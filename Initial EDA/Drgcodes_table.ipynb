# %% [markdown]
# ### Drgcodes table

# %%
#import libraries
import os
import gzip
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file ='C:/Users/zuoch/Downloads/Final semester/DAB304- Health analytics/mimic-iii-clinical-database-1.4/DRGCODES.csv.gz'
drgcodes = pd.read_csv(file, compression ='gzip')
drgcodes
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID DRG_TYPE  DRG_CODE  \
# 0          342        2491   144486     HCFA        28
# 1          343       24958   162910     HCFA       110
# 2          344       18325   153751     HCFA       390
# 3          345       17887   182692     HCFA        14
# 4          346       11113   157980     HCFA       390
# ...        ...         ...      ...      ...       ...
# 125552  123452       71582   101422       MS       221
# 125553  123453       46449   110075     APR       1653
# 125554  123454       46449   110075     APR       1653
# 125555  123455       46449   110075       MS       234
# 125556  123456       87879   155607     APR       6813
#
#                                               DESCRIPTION  DRG_SEVERITY  \
# 0       TRAUMATIC STUPOR & COMA, COMA <1 HR AGE >17 WI...           NaN
# 1       MAJOR CARDIOVASCULAR PROCEDURES WITH COMPLICAT...           NaN
# 2                 NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
# ...

# %%
# Display basic information about the dataset
drgcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125557 entries, 0 to 125556
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ROW_ID         125557 non-null  int64
#  1   SUBJECT_ID     125557 non-null  int64
#  2   HADM_ID        125557 non-null  int64
#  3   DRG_TYPE       125557 non-null  object
#  4   DRG_CODE       125557 non-null  int64
#  5   DESCRIPTION    125494 non-null  object
#  6   DRG_SEVERITY   66634 non-null   float64
#  7   DRG_MORTALITY  66634 non-null   float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.7+ MB

# %%
#checking first rows
drgcodes.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID DRG_TYPE  DRG_CODE  \
# 0     342        2491   144486     HCFA        28
# 1     343       24958   162910     HCFA       110
# 2     344       18325   153751     HCFA       390
# 3     345       17887   182692     HCFA        14
# 4     346       11113   157980     HCFA       390
#
#                                          DESCRIPTION  DRG_SEVERITY  \
# 0  TRAUMATIC STUPOR & COMA, COMA <1 HR AGE >17 WI...           NaN
# 1  MAJOR CARDIOVASCULAR PROCEDURES WITH COMPLICAT...           NaN
# 2            NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
# 3  SPECIFIC CEREBROVASCULAR DISORDERS EXCEPT TRAN...           NaN
# 4            NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
#
#    DRG_MORTALITY
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
#checking number of the columns and rows
drgcodes.shape
# Out:
# (125557, 8)

# %%
# Check for missing values
print("\nMissing Values:")
print(drgcodes.isnull().sum())
# Out:
# Missing Values:
# ROW_ID               0
# SUBJECT_ID           0
# HADM_ID              0
# DRG_TYPE             0
# DRG_CODE             0
# DESCRIPTION         63
# DRG_SEVERITY     58923
# DRG_MORTALITY    58923
# dtype: int64

# %%
# Display summary statistics for numerical columns
numeric_stats = drgcodes.describe()
numeric_stats
# Out:
#               ROW_ID     SUBJECT_ID        HADM_ID       DRG_CODE  \
# count  125557.000000  125557.000000  125557.000000  125557.000000
# mean    62779.000000   41762.886418  150050.705600    1822.518378
# std     36245.328212   29280.952006   28877.584972    2371.218205
# min         1.000000       2.000000  100001.000000       1.000000
# 25%     31390.000000   17302.000000  125042.000000     250.000000
# 50%     62779.000000   31054.000000  150158.000000     619.000000
# 75%     94168.000000   66957.000000  175035.000000    2074.000000
# max    125557.000000   99999.000000  199999.000000    9550.000000
#
#        DRG_SEVERITY  DRG_MORTALITY
# count  66634.000000   66634.000000
# mean       2.978104       2.669643
# std        0.929275       1.102936
# min        0.000000       0.000000
# 25%        2.000000       2.000000
# 50%        3.000000       3.000000
# 75%        4.000000       4.000000
# max        4.000000       4.000000

# %%
#replace the missing value 

drgcodes['DESCRIPTION'].fillna('No record', inplace=True)
drgcodes['DRG_SEVERITY'].fillna('Unknown', inplace=True)
drgcodes['DRG_MORTALITY'].fillna('Unknown', inplace=True)

# %%
#checking missing values after changes
drgcodes.isnull().sum()
# Out:
# ROW_ID           0
# SUBJECT_ID       0
# HADM_ID          0
# DRG_TYPE         0
# DRG_CODE         0
# DESCRIPTION      0
# DRG_SEVERITY     0
# DRG_MORTALITY    0
# dtype: int64

# %%
# Displaying the first few rows of the DataFrame:
drgcodes.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID DRG_TYPE  DRG_CODE  \
# 0     342        2491   144486     HCFA        28
# 1     343       24958   162910     HCFA       110
# 2     344       18325   153751     HCFA       390
# 3     345       17887   182692     HCFA        14
# 4     346       11113   157980     HCFA       390
#
#                                          DESCRIPTION DRG_SEVERITY  \
# 0  TRAUMATIC STUPOR & COMA, COMA <1 HR AGE >17 WI...      Unknown
# 1  MAJOR CARDIOVASCULAR PROCEDURES WITH COMPLICAT...      Unknown
# 2            NEONATE WITH OTHER SIGNIFICANT PROBLEMS      Unknown
# 3  SPECIFIC CEREBROVASCULAR DISORDERS EXCEPT TRAN...      Unknown
# 4            NEONATE WITH OTHER SIGNIFICANT PROBLEMS      Unknown
#
#   DRG_MORTALITY
# 0       Unknown
# 1       Unknown
# 2       Unknown
# 3       Unknown
# 4       Unknown

# %%
#save clean data into csv file

csv_path = 'drgcodes_table_clean.csv'
drgcodes.to_csv(csv_path,
                   index = False)
