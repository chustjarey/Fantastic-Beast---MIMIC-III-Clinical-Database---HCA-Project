# %%
import pandas as pd
import numpy as np

# %%
# reading gzip file
file ='C:/Users/91773/Documents/Healthcare/Data/TRANSFERS.csv.gz'
Transfer_df = pd.read_csv(file, compression ='gzip')
Transfer_df
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID    DBSOURCE  EVENTTYPE  \
# 0          657         111   192123    254245.0     carevue   transfer
# 1          658         111   192123         NaN     carevue   transfer
# 2          659         111   192123         NaN     carevue  discharge
# 3          660         111   155897    249202.0  metavision      admit
# 4          661         111   155897         NaN  metavision   transfer
# ...        ...         ...      ...         ...         ...        ...
# 261892  259671       98385   195599         NaN  metavision   transfer
# 261893  259672       98385   195599    292167.0  metavision   transfer
# 261894  259673       98385   195599         NaN  metavision  discharge
# 261895  259674       98389   155368         NaN  metavision      admit
# 261896  259675       98389   155368         NaN  metavision   transfer
#
#        PREV_CAREUNIT CURR_CAREUNIT  PREV_WARDID  CURR_WARDID  \
# ...

# %%
Transfer_df.shape
# Out:
# (261897, 13)

# %%
Transfer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261897 entries, 0 to 261896
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ROW_ID         261897 non-null  int64
#  1   SUBJECT_ID     261897 non-null  int64
#  2   HADM_ID        261897 non-null  int64
#  3   ICUSTAY_ID     87721 non-null   float64
#  4   DBSOURCE       261656 non-null  object
#  5   EVENTTYPE      261873 non-null  object
#  6   PREV_CAREUNIT  96009 non-null   object
#  7   CURR_CAREUNIT  96016 non-null   object
#  8   PREV_WARDID    202964 non-null  float64
#  9   CURR_WARDID    202954 non-null  float64
#  10  INTIME         261873 non-null  object
#  11  OUTTIME        202921 non-null  object
#  12  LOS            202921 non-null  float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 26.0+ MB

# %%
Transfer_df.isnull()
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  DBSOURCE  EVENTTYPE  \
# 0        False       False    False       False     False      False
# 1        False       False    False        True     False      False
# 2        False       False    False        True     False      False
# 3        False       False    False       False     False      False
# 4        False       False    False        True     False      False
# ...        ...         ...      ...         ...       ...        ...
# 261892   False       False    False        True     False      False
# 261893   False       False    False       False     False      False
# 261894   False       False    False        True     False      False
# 261895   False       False    False        True     False      False
# 261896   False       False    False        True     False      False
#
#         PREV_CAREUNIT  CURR_CAREUNIT  PREV_WARDID  CURR_WARDID  INTIME  \
# ...

# %%
# change the type of column
Transfer_df['INTIME']= pd.to_datetime(Transfer_df['INTIME'])
print(data.dtypes)
# Out:
# ROW_ID                    int64
# SUBJECT_ID                int64
# HADM_ID                   int64
# ICUSTAY_ID               object
# DBSOURCE                 object
# EVENTTYPE                object
# PREV_CAREUNIT            object
# CURR_CAREUNIT            object
# PREV_WARDID              object
# CURR_WARDID              object
# INTIME           datetime64[ns]
# OUTTIME          datetime64[ns]
# LOS                     float64
# dtype: object

# %%
# change the type of column
Transfer_df['OUTTIME']= pd.to_datetime(Transfer_df['OUTTIME'])
print(data.dtypes)
# Out:
# ROW_ID                    int64
# SUBJECT_ID                int64
# HADM_ID                   int64
# ICUSTAY_ID               object
# DBSOURCE                 object
# EVENTTYPE                object
# PREV_CAREUNIT            object
# CURR_CAREUNIT            object
# PREV_WARDID              object
# CURR_WARDID              object
# INTIME           datetime64[ns]
# OUTTIME          datetime64[ns]
# LOS                     float64
# dtype: object

# %%
# changing column type from float to string
Transfer_df['ICUSTAY_ID']= Transfer_df['ICUSTAY_ID'].astype(str)
Transfer_df['PREV_WARDID']= Transfer_df['PREV_WARDID'].astype(str)
Transfer_df['CURR_WARDID']= Transfer_df['CURR_WARDID'].astype(str)
print(Transfer_df.dtypes)
# Out:
# ROW_ID                    int64
# SUBJECT_ID                int64
# HADM_ID                   int64
# ICUSTAY_ID               object
# DBSOURCE                 object
# EVENTTYPE                object
# PREV_CAREUNIT            object
# CURR_CAREUNIT            object
# PREV_WARDID              object
# CURR_WARDID              object
# INTIME           datetime64[ns]
# OUTTIME          datetime64[ns]
# LOS                     float64
# dtype: object

# %%
# removing the '.0' value in the  below ids

Transfer_df['ICUSTAY_ID']= Transfer_df['ICUSTAY_ID'].str.replace('.0', '')
Transfer_df['PREV_WARDID']= Transfer_df['PREV_WARDID'].str.replace('.0', '')
Transfer_df['CURR_WARDID']= Transfer_df['CURR_WARDID'].str.replace('.0', '')
# Out:
# C:\Users\91773\AppData\Local\Temp\ipykernel_7728\1527830486.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   Transfer_df['ICUSTAY_ID']= Transfer_df['ICUSTAY_ID'].str.replace('.0', '')
# C:\Users\91773\AppData\Local\Temp\ipykernel_7728\1527830486.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   Transfer_df['PREV_WARDID']= Transfer_df['PREV_WARDID'].str.replace('.0', '')
# C:\Users\91773\AppData\Local\Temp\ipykernel_7728\1527830486.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   Transfer_df['CURR_WARDID']= Transfer_df['CURR_WARDID'].str.replace('.0', '')

# %%
Transfer_df
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID ICUSTAY_ID    DBSOURCE  EVENTTYPE  \
# 0          657         111   192123     254245     carevue   transfer
# 1          658         111   192123        nan     carevue   transfer
# 2          659         111   192123        nan     carevue  discharge
# 3          660         111   155897       2492  metavision      admit
# 4          661         111   155897        nan  metavision   transfer
# ...        ...         ...      ...        ...         ...        ...
# 261892  259671       98385   195599        nan  metavision   transfer
# 261893  259672       98385   195599     292167  metavision   transfer
# 261894  259673       98385   195599        nan  metavision  discharge
# 261895  259674       98389   155368        nan  metavision      admit
# 261896  259675       98389   155368        nan  metavision   transfer
#
#        PREV_CAREUNIT CURR_CAREUNIT PREV_WARDID CURR_WARDID  \
# 0                CCU          MICU           7          23
# ...

# %%
Transfer_df.isnull().sum()
# Out:
# ROW_ID                0
# SUBJECT_ID            0
# HADM_ID               0
# ICUSTAY_ID            0
# DBSOURCE            241
# EVENTTYPE            24
# PREV_CAREUNIT    165888
# CURR_CAREUNIT    165881
# PREV_WARDID           0
# CURR_WARDID           0
# INTIME               24
# OUTTIME           58976
# LOS               58976
# dtype: int64

# %%
# replace the null value with NaN
Transfer_df['DBSOURCE'].replace({None: np.nan}, inplace=True)
Transfer_df['EVENTTYPE'].replace({None: np.nan}, inplace=True)
Transfer_df['PREV_CAREUNIT'].replace({None: np.nan}, inplace=True)
Transfer_df['CURR_CAREUNIT'].replace({None: np.nan}, inplace=True)

# %%
Transfer_df
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID ICUSTAY_ID    DBSOURCE  EVENTTYPE  \
# 0          657         111   192123     254245     carevue   transfer
# 1          658         111   192123        nan     carevue   transfer
# 2          659         111   192123        nan     carevue  discharge
# 3          660         111   155897       2492  metavision      admit
# 4          661         111   155897        nan  metavision   transfer
# ...        ...         ...      ...        ...         ...        ...
# 261892  259671       98385   195599        nan  metavision   transfer
# 261893  259672       98385   195599     292167  metavision   transfer
# 261894  259673       98385   195599        nan  metavision  discharge
# 261895  259674       98389   155368        nan  metavision      admit
# 261896  259675       98389   155368        nan  metavision   transfer
#
#        PREV_CAREUNIT CURR_CAREUNIT PREV_WARDID CURR_WARDID  \
# 0                CCU          MICU           7          23
# ...

# %%
Transfer_df['CURR_CAREUNIT'].unique()
# Out:
# array(['MICU', nan, 'TSICU', 'CSRU', 'SICU', 'NICU', 'NWARD', 'CCU'],
#       dtype=object)

# %%
Transfer_df['PREV_CAREUNIT'].replace('nan', np.nan, inplace=True)

# %%
Transfer_df['PREV_CAREUNIT'].unique()
# Out:
# array(['CCU', 'MICU', nan, 'TSICU', 'CSRU', 'SICU', 'NICU', 'NWARD'],
#       dtype=object)

# %%
# as we cannot use NaN to replace null value in date or time column instead we use NaT 'not a time'
Transfer_df['INTIME'].fillna(pd.NaT, inplace=True)
Transfer_df['OUTTIME'].fillna(pd.NaT, inplace=True)

# %%
Transfer_df.isnull().sum()
# Out:
# ROW_ID                0
# SUBJECT_ID            0
# HADM_ID               0
# ICUSTAY_ID            0
# DBSOURCE            241
# EVENTTYPE            24
# PREV_CAREUNIT    165888
# CURR_CAREUNIT    165881
# PREV_WARDID           0
# CURR_WARDID           0
# INTIME               24
# OUTTIME           58976
# LOS               58976
# dtype: int64

# %%
#eventhough we convert the null values to NaN it still count nan as null when we calculate the sum of null in the data
Transfer_df.isna().sum()
# Out:
# ROW_ID                0
# SUBJECT_ID            0
# HADM_ID               0
# ICUSTAY_ID            0
# DBSOURCE            241
# EVENTTYPE            24
# PREV_CAREUNIT    165888
# CURR_CAREUNIT    165881
# PREV_WARDID           0
# CURR_WARDID           0
# INTIME               24
# OUTTIME           58976
# LOS               58976
# dtype: int64

# %%
Transfer_df
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID ICUSTAY_ID    DBSOURCE  EVENTTYPE  \
# 0          657         111   192123     254245     carevue   transfer
# 1          658         111   192123        nan     carevue   transfer
# 2          659         111   192123        nan     carevue  discharge
# 3          660         111   155897       2492  metavision      admit
# 4          661         111   155897        nan  metavision   transfer
# ...        ...         ...      ...        ...         ...        ...
# 261892  259671       98385   195599        nan  metavision   transfer
# 261893  259672       98385   195599     292167  metavision   transfer
# 261894  259673       98385   195599        nan  metavision  discharge
# 261895  259674       98389   155368        nan  metavision      admit
# 261896  259675       98389   155368        nan  metavision   transfer
#
#        PREV_CAREUNIT CURR_CAREUNIT PREV_WARDID CURR_WARDID  \
# 0                CCU          MICU           7          23
# ...

# %%
csv_path = 'Table-TRANSFER_clean_data.csv'
Transfer_df.to_csv(csv_path,
                   index = False)
